# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/datasets/population/master/data/population.csv"
data = pd.read_csv(url)

# %%
data_2020 = data[data['Year'] == 2020]
data_2020.head()
# Out:
#                     Country Name Country Code  Year        Value
# 60                         Aruba          ABW  2020     108587.0
# 124  Africa Eastern and Southern          AFE  2020  694446100.0
# 188                  Afghanistan          AFG  2020   39068979.0
# 252   Africa Western and Central          AFW  2020  474569351.0
# 316                       Angola          AGO  2020   33451132.0

# %%
brazil_data = data[data['Country Name'] == 'Brazil']
brazil_data.head()
# Out:
#      Country Name Country Code  Year       Value
# 1856       Brazil          BRA  1960  72388126.0
# 1857       Brazil          BRA  1961  74605447.0
# 1858       Brazil          BRA  1962  76865323.0
# 1859       Brazil          BRA  1963  79164235.0
# 1860       Brazil          BRA  1964  81488595.0

# %% [markdown]
# # 2020 -> 2024

# %%
brazil_data = data_filtered[data_filtered['Country Name'] == 'Brazil']

# %%
data_filtered = data[(data['Year'] >= 2020) & (data['Year'] <= 2024)]

# %%
plt.figure(figsize=(10,6))
plt.plot(brazil_data['Year'], brazil_data['Value'], marker='o', linestyle='-', color='b', label='População do Brasil')

# %% [markdown]
# ### Taxa de crescimento anual

# %%
brazil_data = data_filtered[data_filtered['Country Name'] == 'Brazil'].copy()
brazil_data['Growth Rate'] = brazil_data['Value'].pct_change() * 100

# %%
print(brazil_data[['Year', 'Growth Rate']])
# Out:
#       Year  Growth Rate
# 1916  2020          NaN
# 1917  2021     0.426267
# 1918  2022     0.360830
# 1919  2023     0.396714

# %%
plt.figure(figsize=(10,6))
plt.bar(brazil_data['Year'], brazil_data['Growth Rate'], color='b', alpha=0.7)

plt.title('Taxa de Crescimento Anual da População do Brasil (2020-2024)')
plt.xlabel('Ano')
plt.ylabel('Taxa de Crescimento (%)')
plt.grid(True, axis='y')
plt.xticks(brazil_data['Year'], rotation=0)

plt.show()
