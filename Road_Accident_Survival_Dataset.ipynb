# %%
# Importando as bibliotecas

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import kagglehub

# %%
# Carregando a base de dados

path = kagglehub.dataset_download("himelsarder/road-accident-survival-dataset")
os.environ['KAGLE_CONFIG_DIR'] = '/content'
print("Path to dataset files:", path)
os.listdir(path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/himelsarder/road-accident-survival-dataset/versions/1
# ['accident.csv']

# %%
path = '/root/.cache/kagglehub/datasets/himelsarder/road-accident-survival-dataset/versions/1'
df = pd.read_csv(path + '/accident.csv')

# %% [markdown]
# ## Propriedades dos dados:

# %%
# Verificando as linhas iniciais do dataset
df.head()
# Out:
#    Age  Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived
# 0   56  Female             27.0          No            No         1
# 1   69  Female             46.0          No           Yes         1
# 2   46    Male             46.0         Yes           Yes         0
# 3   32    Male            117.0          No           Yes         0
# 4   60  Female             40.0         Yes           Yes         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              200 non-null    int64
#  1   Gender           199 non-null    object
#  2   Speed_of_Impact  197 non-null    float64
#  3   Helmet_Used      200 non-null    object
#  4   Seatbelt_Used    200 non-null    object
#  5   Survived         200 non-null    int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.5+ KB

# %% [markdown]
# # Analises sobre as frequências:

# %%
# Gráfico com as idades mais recorrentes dos acidentes
plt.figure(figsize=(20, 10))
plt.title("Frequência da idade")
plt.xlabel("Age")
plt.ylabel("Frequency")
df['Age'].value_counts().plot(kind='bar')
plt.grid(axis='y', color='black')
plt.xticks(rotation=45)
plt.show()

# %%
qtd_age = df['Age'].value_counts().reset_index(name='Frequency')
qtd_age.columns = ['Age', 'Frequency']
qtd_age
# Out:
#     Age  Frequency
# 0    56          9
# 1    61          9
# 2    41          7
# 3    45          7
# 4    32          7
# 5    31          6
# 6    25          6
# 7    52          6
# 8    18          5
# 9    26          5
# 10   24          5
# 11   68          5
# 12   43          5
# 13   59          5
# 14   42          5
# 15   62          5
# 16   64          5
# 17   19          5
# 18   46          4
# 19   21          4
# 20   50          4
# 21   39          4
# 22   20          4
# 23   44          4
# 24   57          4
# 25   69          4
# 26   53          4
# 27   28          4
# 28   40          4
# 29   54          4
# 30   38          4
# 31   30          3
# 32   58          3
# 33   49          3
# 34   35          3
# 35   47          3
# 36   51          2
# 37   22          2
# 38   29          2
# 39   65          2
# 40   67          2
# 41   60          2
# 42   23          2
# 43   34          2
# 44   66          2
# 45   37          2
# ...

# %%
plt.figure(figsize=(20, 10))
plt.title("Relação entre idade e a sobrevivência")
plt.xlabel("Idade")
plt.ylabel("Frequency")
sns.countplot(x='Age', hue='Survived', data=df)
plt.grid(axis='y', color='black')
plt.xticks(rotation=45)
plt.legend(title='Sobreviveu?', loc='upper left', bbox_to_anchor=(1, 1), frameon=False, fontsize=10)
# Alterando a legenda
handles, labels = plt.gca().get_legend_handles_labels()
# Substituindo 0 e 1 por "Não" e "Sim"
new_labels = ['Não' if label == '0' else 'Sim' for label in labels]
# Atualizando a legenda com os novos rótulos
plt.legend(handles, new_labels)
plt.show()

# %%
# Gráfico com os gêneros ligados aos acidenes

plt.figure(figsize=(20, 10))
plt.title("Frequência dos gêneros")
plt.xlabel("Gender")
plt.ylabel("Frequency")
df['Gender'].value_counts().plot(kind='bar')
plt.grid(axis='y', color='black')
plt.xticks(rotation=45)
plt.show()

# %%
qtd_age = df['Gender'].value_counts().reset_index(name='Frequency')
qtd_age.columns = ['Gender', 'Frequency']
qtd_age
# Out:
#    Gender  Frequency
# 0  Female        110
# 1    Male         89

# %%
plt.figure(figsize=(20, 10))
plt.title("Relação entre gênero e a sobrevivência")
plt.xlabel("Gender")
plt.ylabel("Frequency")
sns.countplot(x='Gender', hue='Survived', data=df)
plt.grid(axis='y', color='black')
plt.xticks(rotation=45)
# Alterando a legenda
handles, labels = plt.gca().get_legend_handles_labels()
# Substituindo 0 e 1 por "Não" e "Sim"
new_labels = ['Não' if label == '0' else 'Sim' for label in labels]
# Atualizando a legenda com os novos rótulos
plt.legend(handles, new_labels)
plt.show()

# %%
# Gráfico com as idades mais recorrentes dos acidentes

plt.figure(figsize=(20, 10))
plt.title("Frequência da velocidade de impacto")
plt.xlabel("Speed_of_Impact")
plt.ylabel("Frequency")
df['Speed_of_Impact'].value_counts().plot(kind='bar')
plt.grid(axis='y', color='black')
plt.xticks(rotation=90)
plt.show()

# %%
qtd_age = df['Speed_of_Impact'].value_counts().reset_index(name='Frequency')
qtd_age.columns = ['Speed_of_Impact', 'Frequency']
qtd_age
# Out:
#     Speed_of_Impact  Frequency
# 0              77.0          7
# 1              35.0          6
# 2              88.0          6
# 3             109.0          5
# 4              82.0          5
# ..              ...        ...
# 75             39.0          1
# 76             64.0          1
# 77             55.0          1
# 78             26.0          1
# 79            103.0          1
#
# [80 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
plt.title("Relação entre a velocidade do impacto e a sobrevivência")
plt.xlabel("Speed_of_Impact")
plt.ylabel("Frequency")
sns.countplot(x='Speed_of_Impact', hue='Survived', data=df)
plt.grid(axis='y', color='black')
plt.xticks(rotation=90)
# Alterando a legenda
handles, labels = plt.gca().get_legend_handles_labels()
# Substituindo 0 e 1 por "Não" e "Sim"
new_labels = ['Não' if label == '0' else 'Sim' for label in labels]
# Atualizando a legenda com os novos rótulos
plt.legend(handles, new_labels)
plt.show()

# %%
# Gráfico sobre o uso dos capactes nos acidentes
plt.figure(figsize=(20, 10))
plt.title("Frequência do uso de capacete")
plt.xlabel("Helmet_Used")
plt.ylabel("Frequency")
df['Helmet_Used'].value_counts().plot(kind='bar')
plt.grid(axis='y', color='black')
plt.xticks(rotation=45)
plt.show()

# %%
qtd_age = df['Helmet_Used'].value_counts().reset_index(name='Frequency')
qtd_age.columns = ['Helmet_Used', 'Frequency']
qtd_age
# Out:
#   Helmet_Used  Frequency
# 0         Yes        111
# 1          No         89

# %%
# Gráfico sobre o uso do cinto de segurança nos acidentes

plt.figure(figsize=(20, 10))
plt.title("Frequência da idade")
plt.xlabel("Seatbelt_Used")
plt.ylabel("Frequency")
df['Seatbelt_Used'].value_counts().plot(kind='bar')
plt.grid(axis='y', color='black')
plt.xticks(rotation=45)
plt.show()

# %%
qtd_age = df['Seatbelt_Used'].value_counts().reset_index(name='Frequency')
qtd_age.columns = ['Seatbelt_Used', 'Frequency']
qtd_age
# Out:
#   Seatbelt_Used  Frequency
# 0           Yes        111
# 1            No         89

# %% [markdown]
# # ML:

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import classification_report, accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.get_dummies(df,columns=["Gender","Helmet_Used", "Seatbelt_Used"],drop_first=True).fillna(0).astype(int)

# %%
X = df.drop("Survived", axis=1)
y = df['Survived']
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.20,random_state=42)

# %% [markdown]
# Vamos aplicar alguns algoritmos e depois tratar os dados para ver a diferença de desempenho

# %%
#Criando e treinando o modelo
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Faça previsões
y_pred = model.predict(X_test)

# Avalie o modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Acurácia: {accuracy}')
# Out:
# Acurácia: 0.51875

# %%
# Treinamento do modelo
model = LinearRegression()
model.fit(X_train, y_train)

# Previsões
y_pred = model.predict(X_test)
model.score(X_test,y_test)
# Out:
# -0.11119047365608425

# %%
# RFC
# Treinamento do modelo
rfc_model = RandomForestClassifier(random_state=42)
rfc_model.fit(X_train, y_train)

# Previsões
y_pred = rfc_model.predict(X_test)
rfc_model.score(X_test,y_test)
# Out:
# 0.53125

# %% [markdown]
# # Normalizar os dados

# %%
scaler_minmax = MinMaxScaler()
X_train_normalized = scaler_minmax.fit_transform(X_train)
X_test_normalized = scaler_minmax.transform(X_test)

# Treinar o modelo com os dados normalizados
model.fit(X_train_normalized, y_train)
y_pred_normalized = model.predict(X_test_normalized)

print("Desempenho com Normalização (MinMaxScaler):")
print(classification_report(y_test, y_pred_normalized))
# Out:
# Desempenho com Normalização (MinMaxScaler):
#               precision    recall  f1-score   support
#
#            0       0.50      0.20      0.28        82
#            1       0.48      0.79      0.60        78
#
#     accuracy                           0.49       160
#    macro avg       0.49      0.49      0.44       160
# weighted avg       0.49      0.49      0.44       160

# %%
# RFC
# Treinamento do modelo
rfc_model = RandomForestClassifier(random_state=42)
rfc_model.fit(X_train, y_train)

# Previsões
y_pred = rfc_model.predict(X_test)
rfc_model.score(X_test,y_test)
# Out:
# 0.53125

# %%
#Criando e treinando o modelo
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Faça previsões
y_pred = model.predict(X_test)

# Avalie o modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Acurácia: {accuracy}')
# Out:
# Acurácia: 0.575

# %% [markdown]
# # Padronizar os dados

# %%
scaler_standard = StandardScaler()
X_train_scaled = scaler_standard.fit_transform(X_train)
X_test_scaled = scaler_standard.transform(X_test)

# Treinar o modelo com os dados padronizados
model = LogisticRegression()
model.fit(X_train_scaled, y_train)
y_pred_standard = model.predict(X_test_scaled)

print("Desempenho com Padronização (StandardScaler):")
print(classification_report(y_test, y_pred_standard))
# Out:
# Desempenho com Padronização (StandardScaler):
#               precision    recall  f1-score   support
#
#            0       0.49      0.27      0.35        82
#            1       0.48      0.71      0.57        78
#
#     accuracy                           0.48       160
#    macro avg       0.48      0.49      0.46       160
# weighted avg       0.48      0.48      0.46       160

# %%
#Criando e treinando o modelo
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Faça previsões
y_pred = model.predict(X_test)

# Avalie o modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Acurácia: {accuracy}')
# Out:
# Acurácia: 0.5625
